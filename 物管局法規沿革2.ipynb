# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.support import expected_conditions as EC
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup


WIDTH = 1200
HEIGHT = 1000
#WIDTH = 1000
#HEIGHT = 600

PIXEL_RATIO = 3.0
#UA = 'Mozilla/5.0 (Linux; Android 4.1.1; GT-N7100 Build/JRO03C) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/35.0.1916.138 Mobile Safari/537.36 T7/6.3'
UA = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3) AppleWebKit/535.20 (KHTML, like Gecko) Chrome/19.0.1036.7 Safari/535.20'

mobileEmulation = {"deviceMetrics": {"width": WIDTH, "height": HEIGHT, "pixelRatio": PIXEL_RATIO}, "userAgent": UA}
options = webdriver.ChromeOptions()
options.add_experimental_option('mobileEmulation', mobileEmulation)

# %%
driver = webdriver.Chrome(executable_path='chromedriver.exe', chrome_options=options)
#driver.get('https://www.skyscanner.com.tw/transport/flights/tpet/cdg/190310/190322/?adultsv2=1&childrenv2=&cabinclass=economy&rtn=1&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&qp_prevProvider=ins_month&qp_prevCurrency=TWD&qp_prevPrice=16825&priceSourceId=taps-taps&priceTrace=201810280441*I*TPE*CDG*20190310*chin*CA%7C201810280441*I*CDG*TPE*20190322*chin*CA#results')




url = 'https://www.aec.gov.tw'

#requests.get(url)

driver.get(url)

#https://www.tigerairtw.com/zh-tw/

# %%
driver = webdriver.Chrome(executable_path='chromedriver.exe', chrome_options=options)
#driver.get('https://www.skyscanner.com.tw/transport/flights/tpet/cdg/190310/190322/?adultsv2=1&childrenv2=&cabinclass=economy&rtn=1&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&qp_prevProvider=ins_month&qp_prevCurrency=TWD&qp_prevPrice=16825&priceSourceId=taps-taps&priceTrace=201810280441*I*TPE*CDG*20190310*chin*CA%7C201810280441*I*CDG*TPE*20190322*chin*CA#results')




url = 'http://erss.aec.gov.tw/law/LawCategoryMain.aspx?CategoryID=006'

#requests.get(url)

driver.get(url)

#https://www.tigerairtw.com/zh-tw/

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
tag=soup.title
print(tag)
# Out:
# <title>
# 	行政院原子能委員會主管法規共用系統-法規體系-放射性物料
# </title>

# %%
ls=soup.tr.string
print(ls)
# Out:
# None

# %%
ss=soup.body.a.string
print(ss)
# Out:
# 跳到主要內容區塊

# %%
driver = webdriver.Chrome(executable_path='chromedriver.exe', chrome_options=options)
for url in kt:
    driver.get(url)
    driver.implicitly_wait(30)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.implicitly_wait(30)
    b_tags=soup.select('#content > div > div.well.law-reg.law-content')
for b in b_tags:
    print(b.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-6c930691a39c> in <module>
#       1 driver = webdriver.Chrome(executable_path='chromedriver.exe', chrome_options=options)
# ----> 2 for url in kt:
#       3     driver.get(url)
#       4     driver.implicitly_wait(30)
#       5     soup = BeautifulSoup(driver.page_source, 'html.parser')
#
# NameError: name 'kt' is not defined

# %%
#print(soup.find_all('tr'))
a_tags = soup.select('a[href^="LawContent.aspx?id"]')
print(a_tags)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b1b08f99736d> in <module>
#       1
#       2 #print(soup.find_all('tr'))
# ----> 3 a_tags = soup.select('a[href^="LawContent.aspx?id"]')
#       4 print(a_tags)
#
# NameError: name 'soup' is not defined

# %%
import numpy as np
import pandas as pd
import pandas
author_ids = [] # 建立一個空的 list 來放置名稱
web=[]#建立連結

posts =soup.select('td.aCenter a')
for post in posts:
    try:
        author_ids.extend(post)
    except:
        author_ids.extend(np.nan)


                
ptt_nba_dict= {"名稱": author_ids}

#print(author_ids)
ptt_nba_df = pd.DataFrame(ptt_nba_dict)
ptt_nba_df
# Out:
#                                    名稱
# 0                 低放射性廢棄物最終處置設施場址設置條例
# 1                            放射性物料管理法
# 2                       放射性物料研究發展獎勵辦法
# 3         低放射性廢棄物最終處置設施場址禁置地區之範圍及認定標準
# 4                         放射性物料管制收費標準
# 5                        放射性廢棄物運作許可辦法
# 6               高放射性廢棄物最終處置及其設施安全管理規則
# 7               低放射性廢棄物最終處置及其設施安全管理規則
# 8                        核子原料運作安全管理規則
# 9                        核子燃料運作安全管理規則
# 10                       放射性物料管理法施行細則
# 11               放射性廢棄物處理設施運轉人員資格管理辦法
# 12         放射性廢棄物處理貯存最終處置設施建造執照申請審核辦法
# 13               放射性廢棄物處理貯存及其設施安全管理規則
# 14           核子原料核子燃料生產貯存設施建造執照申請審核辦法
# 15                   天然放射性物質衍生廢棄物管理辦法
# 16                      放射性物料設施委託檢查辦法
# 17               一定活度或比活度以下放射性廢棄物管理辦法
# 18                       核子原料礦及礦物管理辦法
# 19  行政院原子能委員會放射性物料管理局放射性物料安全營運績優獎實施要點
# 20     放射性物料營運技術及最終處置之研究發展計畫認定作業程序及原則
# 21            行政院原子能委員會放射性物料安全諮詢會設置要點
# 22             用過核子燃料乾式貯存設施安全分析報告審查導則
# 23           申請設置用過核子燃料乾式貯存設施安全分析報告導則
# ...

# %%
ptt_nba_df.row[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-8d22fb977b7d> in <module>
# ----> 1 ptt_nba_df.row[0]
#
# c:\python\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'row'

# %%
#print(soup.find_all('tr'))
a_tags = soup.select('td.aCenter a')
#print(a_tags)
for t in a_tags:
    print(t.text)
# Out:
# 低放射性廢棄物最終處置設施場址設置條例
# 放射性物料管理法
# 放射性物料研究發展獎勵辦法
# 低放射性廢棄物最終處置設施場址禁置地區之範圍及認定標準
# 放射性物料管制收費標準
# 放射性廢棄物運作許可辦法
# 高放射性廢棄物最終處置及其設施安全管理規則
# 低放射性廢棄物最終處置及其設施安全管理規則
# 核子原料運作安全管理規則
# 核子燃料運作安全管理規則
# 放射性物料管理法施行細則
# 放射性廢棄物處理設施運轉人員資格管理辦法
# 放射性廢棄物處理貯存最終處置設施建造執照申請審核辦法
# 放射性廢棄物處理貯存及其設施安全管理規則
# 核子原料核子燃料生產貯存設施建造執照申請審核辦法
# 天然放射性物質衍生廢棄物管理辦法
# 放射性物料設施委託檢查辦法
# 一定活度或比活度以下放射性廢棄物管理辦法
# 核子原料礦及礦物管理辦法
# 行政院原子能委員會放射性物料管理局放射性物料安全營運績優獎實施要點
# 放射性物料營運技術及最終處置之研究發展計畫認定作業程序及原則
# 行政院原子能委員會放射性物料安全諮詢會設置要點
# 用過核子燃料乾式貯存設施安全分析報告審查導則
# 申請設置用過核子燃料乾式貯存設施安全分析報告導則
# 違反放射性物料管理法第二十九條第一項之罰鍰裁量基準
# 低放射性廢棄物貯存設施再評估報告審查導則
# 低放射性廢棄物貯存設施安全分析報告導則
# 放射性物料設施設計修改及設備變更申請審核作業規範
# 高放射性廢棄物最終處置設施場址規範
# 集中式放射性廢棄物貯存設施場址規範
# 低放射性廢棄物最終處置設施安全分析報告導則
# 有關放射性物料管理法第二十九條規定之解釋令
# 低放射性廢棄物最終處置盛裝容器審查規範
# 低放射性廢棄物盛裝容器使用申請書導則
# 放射性廢棄物處理設施運轉人員訓練計畫審查作業要點
# 放射性物料設施興建申請聽證程序要點
# 申請設置低放射性廢棄物處理設施安全分析報告導則
# 一定活度或比活度以下放射性廢棄物外釋計畫導則
# 放射性廢料管理方針
# 放射性廢料管理辦法
# 放射性廢棄物處理設施運轉人員合格證明書核發作業要點

# %%
a_tags = soup.select('td.aCenter a')

for wq in a_tags: 
    dd= (wq["href"])
    print(dd)

# %%
a_tags = soup.select('td.aCenter a')
kt = []
for wq in a_tags:    
   kt.append('http://erss.aec.gov.tw/law/'+wq["href"])

# %%
driver = webdriver.Chrome(executable_path='chromedriver.exe', chrome_options=options)
for url in kt:
    driver.get(url)
    driver.implicitly_wait(30)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.implicitly_wait(30)
    b_tags=soup.select('#content > div > div.well.law-reg.law-content')
for b in b_tags:
    print(b.text)
# Out:
# 一、為辦理放射性廢棄物處理設施運轉人員合格證明書核發作業，特訂定    本作業要點。二、申請放射性廢棄物處理設施運轉人員合格證明書，應以設施之系統別    提出申請。    前項系統指設有個別操作控制室者。    設施之各系統間具有操作之關聯性，相關系統得併同申請。三、申請運轉人員合格證明書者，應檢具經下列機關 (構) 訓練或再訓練    合格發給之證明書： (一) 主管機關。 (二) 經主管機關核准之放射性廢棄物處理、貯存、最終處置設施或核子      反應器設施經營者。 (三) 經主管機關認可從事相關訓練業務之機構。四、設施系統與操作程序及輻射安全訓練課目如附表一。五、運轉人員接受前點規定之機關 (構) 訓練，訓練之講員應具有下列資    格之一： (一) 教育部認可大專院校相關科系之講師以上者。 (二) 取得教育部認可國內外相關科系研究所碩士學位以上者。 (三) 第三點第二款所列各設施股長以上者。 (四) 教育部認可國內外大專院校相關科系畢業，負責設計或建造處理設      施者。 (五) 具輻射防護師資格者。 (六) 教育部認可國內外大專院校相關科系畢業，並在公、私立機構、學      校、研究單位從事相關實務工作五年以上者。六、申請運轉人員合格證明書者，應依放射性物料管理法施行細則第三十    五條填具申請書 (附件一) ，並檢附現場實習證明及載明下列事項之    訓練合格證明書，向主管機關申請審查合格後，發給合格證明書： (一) 受訓人姓名。 (二) 訓練期程。 (三) 訓練課目名稱。 (四) 訓練時數。 (五) 訓練合格。 (六) 訓練機關 (構) 名稱及負責人姓名。 (七) 證明文件字號及發證日期。    前項現場實習證明應載明下列事項： (一) 實習人姓名。 (二) 實習期程。 (三) 實習設施及操作系統。 (四) 實習機關 (構) 名稱及負責人姓名。 (五) 證明文件字號及發證日期。七、申請放射性廢棄物處理設施運轉人員合格證明書者；其已全程參與設    施之試運轉，得檢附設施經營者出具之試運轉工作證明，免前點之現    場實習證明。八、第六點之運轉人員合格證明書有效期間三年，期滿前九十天至三十天    內，運轉人員得填具換發申請書 (附件二) ，並檢附運轉人員合格證    明書及再訓練合格證明書，向主管機關申請換發。九、運轉人員合格證明書於有
# ...

# %%
import re
#ss=soup.find_all(href=re.compile("LawContent.aspx"))
ss=soup.find_all("",{"href":re.compile("LawContent.aspx")})
#for link in soup.find_all('a'):
#    print (link.get('href'))
#dr=re.compile(r'<[^>]+>',re.S)
#ww=ss.sub('',html)

    
print(ss)
# Out:
# [<a href="LawContent.aspx?id=FL039264" id="ctl00_cp_content_rptList_ctl01_hlkLawName">低放射性廢棄物最終處置設施場址設置條例</a>, <a href="LawContent.aspx?id=FL022706" id="ctl00_cp_content_rptList_ctl02_hlkLawName">放射性物料管理法</a>, <a href="LawContent.aspx?id=FL033419" id="ctl00_cp_content_rptList_ctl03_hlkLawName">放射性物料研究發展獎勵辦法</a>, <a href="LawContent.aspx?id=FL041151" id="ctl00_cp_content_rptList_ctl04_hlkLawName">低放射性廢棄物最終處置設施場址禁置地區之範圍及認定標準</a>, <a href="LawContent.aspx?id=FL025158" id="ctl00_cp_content_rptList_ctl05_hlkLawName">放射性物料管制收費標準</a>, <a href="LawContent.aspx?id=FL027823" id="ctl00_cp_content_rptList_ctl06_hlkLawName">放射性廢棄物運作許可辦法</a>, <a href="LawContent.aspx?id=FL036833" id="ctl00_cp_content_rptList_ctl07_hlkLawName">高放射性廢棄物最終處置及其設施安全管理規則</a>, <a href="LawContent.aspx?id=FL026397" id="ctl00_cp_content_rptList_ctl08_hlkLawName">低放射性廢棄物最終處置及其設施安全管理規則</a>, <a href="LawContent.aspx?id=FL030103" id="ctl00_cp_content_rptList_ctl09_hlkLawName">核子原料運作安全管理規則</a>, <a href="LawContent.aspx?id=FL0300
# ...

# %%
import numpy as np
import pandas as pd
import pandas
author_ids = [] # 建立一個空的 list 來放置名稱
web=[]#建立連結

posts =soup.select('td.aCenter a')
for post in posts:
    try:
        author_ids.extend(post)
    except:
        author_ids.append(np.nan)
    try:
        web.append(post["href"])
    except:
        web.append(np.nan)

                
ptt_nba_dict= {"名稱": author_ids,"連結":web}

#print(author_ids)
ptt_nba_df = pd.DataFrame(ptt_nba_dict)
ptt_nba_df
# Out:
#                                    名稱                           連結
# 0                 低放射性廢棄物最終處置設施場址設置條例  LawContent.aspx?id=FL039264
# 1                            放射性物料管理法  LawContent.aspx?id=FL022706
# 2                       放射性物料研究發展獎勵辦法  LawContent.aspx?id=FL033419
# 3         低放射性廢棄物最終處置設施場址禁置地區之範圍及認定標準  LawContent.aspx?id=FL041151
# 4                         放射性物料管制收費標準  LawContent.aspx?id=FL025158
# 5                        放射性廢棄物運作許可辦法  LawContent.aspx?id=FL027823
# 6               高放射性廢棄物最終處置及其設施安全管理規則  LawContent.aspx?id=FL036833
# 7               低放射性廢棄物最終處置及其設施安全管理規則  LawContent.aspx?id=FL026397
# 8                        核子原料運作安全管理規則  LawContent.aspx?id=FL030103
# 9                        核子燃料運作安全管理規則  LawContent.aspx?id=FL030090
# 10                       放射性物料管理法施行細則  LawContent.aspx?id=FL025664
# 11               放射性廢棄物處理設施運轉人員資格管理辦法  LawContent.aspx?id=GL000003
# 12         放射性廢棄物處理貯存最終處置設施建造執照申請審核辦法  LawContent.aspx?id=FL029272
# ...

# %%
ptt_nba_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 2 columns):
# 名稱    41 non-null object
# 連結    41 non-null object
# dtypes: object(2)
# memory usage: 368.0+ bytes

# %%
print(ptt_nba_df.index)
# Out:
# RangeIndex(start=0, stop=41, step=1)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-134-10b99974848a> in <module>
# ----> 1 ptt_nba_df.rows[0:2]
#
# c:\python\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
driver = webdriver.Chrome(executable_path='chromedriver.exe', chrome_options=options)
url = 'http://erss.aec.gov.tw/law/LawContent.aspx?id=FL039264'
driver.get(url)

# %%
driver = webdriver.Chrome(executable_path='chromedriver.exe', chrome_options=options)
url = 'http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL036832#lawmenu'
driver.get(url)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
#soup.select('td.aCenter a')
#soup.select('#content > div > div.well.law-reg.law-content')
b_tags=soup.select('#content > div > div.well.law-reg.law-content')

for b in b_tags:
    
    print(b.text)
# Out:
# 1.中華民國九十四年八月三十日行政院原子能委員會會物字第 094002892  8 號令訂定發布全文 5  點；並自發文日施行2.中華民國一百零五年九月二日行政院原子能委員會會物字第 105001267  11 號令修正發布全文；並自發文日施行3.中華民國一百零七年八月三十日行政院原子能委員會會物字第 1070010  5294 號令修正發布全文；並自發文日施行

# %%
def filter_tags(htmlstr):
  re_cdata=re.compile('//<!\[CDATA\[[^>]*//\]\]>',re.I) #匹配CDATA
  re_script=re.compile('<\s*script[^>]*>[^<]*<\s*/\s*script\s*>',re.I)#Script
  re_style=re.compile('<\s*style[^>]*>[^<]*<\s*/\s*style\s*>',re.I)#style
  re_br=re.compile('<br\s*?/?>')#处理换行
  re_h=re.compile('</?\w+[^>]*>')#HTML标签
  re_comment=re.compile('<!--[^>]*-->')#HTML注释
  blank_line=re.compile('\n+')

  #过滤匹配内容
  s=re_cdata.sub('',htmlstr)#去掉CDATA
  s=re_script.sub('',s) #去掉SCRIPT
  s=re_style.sub('',s)#去掉style
  s=re_br.sub('\n',s)#将br转换为换行
  s=re_h.sub('',s) #去掉HTML 标签
  s=re_comment.sub('',s)#去掉HTML注释
  s=blank_line.sub('\n',s)#去掉多余的空行

  return())
！

# %%
print(b)
# Out:
# <div class="well law-reg law-content">
# <div class="law-reg-content" id="ctl00_cp_content_divLawContentSource">1.中華民國九十四年八月三十日行政院原子能委員會會物字第 094002892<br/>  8 號令訂定發布全文 5  點；並自發文日施行<br/>2.中華民國一百零五年九月二日行政院原子能委員會會物字第 105001267<br/>  11 號令修正發布全文；並自發文日施行<br/>3.中華民國一百零七年八月三十日行政院原子能委員會會物字第 1070010<br/>  5294 號令修正發布全文；並自發文日施行</div>
# </div>

# %%
print(b)
# Out:
# <div class="well law-reg law-content">
# <div class="law-reg-content" id="ctl00_cp_content_divLawContentSource">1.中華民國九十四年八月三十日行政院原子能委員會會物字第 094002892<br/>  8 號令訂定發布全文 5  點；並自發文日施行<br/>2.中華民國一百零五年九月二日行政院原子能委員會會物字第 105001267<br/>  11 號令修正發布全文；並自發文日施行<br/>3.中華民國一百零七年八月三十日行政院原子能委員會會物字第 1070010<br/>  5294 號令修正發布全文；並自發文日施行</div>
# </div>

# %%
import re
dr = re.compile(r'<[^>]+>',re.S)
dd = dr.sub('',b.text)
print(dd)
# Out:
# 1.中華民國九十四年八月三十日行政院原子能委員會會物字第 094002892  8 號令訂定發布全文 5  點；並自發文日施行2.中華民國一百零五年九月二日行政院原子能委員會會物字第 105001267  11 號令修正發布全文；並自發文日施行3.中華民國一百零七年八月三十日行政院原子能委員會會物字第 1070010  5294 號令修正發布全文；並自發文日施行

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-ba95b4da9448> in <module>
#       1 get_list=[]
#       2 get_list.append[{
# ----> 3 "http://erss.aec.gov.tw/law/LawContent.aspx?id=FL039264,http://erss.aec.gov.tw/law/LawContent.aspx?id=FL011950,http://erss.aec.gov.tw/law/LawContent.aspx?id=FL027824"
#       4 }]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.support import expected_conditions as EC
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup


WIDTH = 1200
HEIGHT = 1000
#WIDTH = 1000
#HEIGHT = 600

PIXEL_RATIO = 3.0
#UA = 'Mozilla/5.0 (Linux; Android 4.1.1; GT-N7100 Build/JRO03C) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/35.0.1916.138 Mobile Safari/537.36 T7/6.3'
UA = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3) AppleWebKit/535.20 (KHTML, like Gecko) Chrome/19.0.1036.7 Safari/535.20'

mobileEmulation = {"deviceMetrics": {"width": WIDTH, "height": HEIGHT, "pixelRatio": PIXEL_RATIO}, "userAgent": UA}
options = webdriver.ChromeOptions()
options.add_experimental_option('mobileEmulation', mobileEmulation)

# %%
driver = webdriver.Chrome(executable_path='chromedriver.exe', chrome_options=options)
#driver.get('https://www.skyscanner.com.tw/transport/flights/tpet/cdg/190310/190322/?adultsv2=1&childrenv2=&cabinclass=economy&rtn=1&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&qp_prevProvider=ins_month&qp_prevCurrency=TWD&qp_prevPrice=16825&priceSourceId=taps-taps&priceTrace=201810280441*I*TPE*CDG*20190310*chin*CA%7C201810280441*I*CDG*TPE*20190322*chin*CA#results')




url = 'http://erss.aec.gov.tw/law/LawCategoryMain.aspx?CategoryID=006'

#requests.get(url)

driver.get(url)

#https://www.tigerairtw.com/zh-tw/

soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
import numpy as np
import pandas as pd
import pandas
author_ids = [] # 建立一個空的 list 來放置名稱
web=[]#建立連結

posts =soup.select('td.aCenter a')
for post in posts:
    try:
        author_ids.extend(post)
    except:
        author_ids.append(np.nan)
    try:
        web.append(post["href"])
    except:
        web.append(np.nan)

                
ptt_nba_dict= {"名稱": author_ids,"連結":web}

#print(author_ids)
ptt_nba_df = pd.DataFrame(ptt_nba_dict)
ptt_nba_df
# Out:
#                                    名稱                           連結
# 0                 低放射性廢棄物最終處置設施場址設置條例  LawContent.aspx?id=FL039264
# 1                            放射性物料管理法  LawContent.aspx?id=FL022706
# 2                       放射性物料研究發展獎勵辦法  LawContent.aspx?id=FL033419
# 3         低放射性廢棄物最終處置設施場址禁置地區之範圍及認定標準  LawContent.aspx?id=FL041151
# 4                         放射性物料管制收費標準  LawContent.aspx?id=FL025158
# 5                        放射性廢棄物運作許可辦法  LawContent.aspx?id=FL027823
# 6               高放射性廢棄物最終處置及其設施安全管理規則  LawContent.aspx?id=FL036833
# 7               低放射性廢棄物最終處置及其設施安全管理規則  LawContent.aspx?id=FL026397
# 8                        核子原料運作安全管理規則  LawContent.aspx?id=FL030103
# 9                        核子燃料運作安全管理規則  LawContent.aspx?id=FL030090
# 10                       放射性物料管理法施行細則  LawContent.aspx?id=FL025664
# 11               放射性廢棄物處理設施運轉人員資格管理辦法  LawContent.aspx?id=GL000003
# 12         放射性廢棄物處理貯存最終處置設施建造執照申請審核辦法  LawContent.aspx?id=FL029272
# ...

# %%
# Out:
# LawContent.aspx?id=FL039264

# %%
posts =soup.select('td.aCenter a')
for post in posts:
    pp=(post["href"])
    #pattern = 'LawContent'    
    post = re.sub('LawContent','LawContentSource',pp)
    print(post)
# Out:
# LawContentSource.aspx?id=FL039264
# LawContentSource.aspx?id=FL022706
# LawContentSource.aspx?id=FL033419
# LawContentSource.aspx?id=FL041151
# LawContentSource.aspx?id=FL025158
# LawContentSource.aspx?id=FL027823
# LawContentSource.aspx?id=FL036833
# LawContentSource.aspx?id=FL026397
# LawContentSource.aspx?id=FL030103
# LawContentSource.aspx?id=FL030090
# LawContentSource.aspx?id=FL025664
# LawContentSource.aspx?id=GL000003
# LawContentSource.aspx?id=FL029272
# LawContentSource.aspx?id=FL026716
# LawContentSource.aspx?id=FL029273
# LawContentSource.aspx?id=FL041714
# LawContentSource.aspx?id=FL038028
# LawContentSource.aspx?id=FL033420
# LawContentSource.aspx?id=FL011949
# LawContentSource.aspx?id=GL000001
# LawContentSource.aspx?id=GL000052
# LawContentSource.aspx?id=GL000002
# LawContentSource.aspx?id=GL000099
# LawContentSource.aspx?id=FL037472
# LawContentSource.aspx?id=GL000095
# LawContentSource.aspx?id=GL000094
# LawContentSource.aspx?id=FL036832
# ...

# %%
a_tags = soup.select('td.aCenter a')
kt = []
for wq in a_tags:    
   kt.append('http://erss.aec.gov.tw/law/'+post+'#lawmenu')

# %%
print(kt)
# Out:
# ['http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL027824#lawmenu', 'http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL027824#lawmenu', 'http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL027824#lawmenu', 'http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL027824#lawmenu', 'http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL027824#lawmenu', 'http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL027824#lawmenu', 'http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL027824#lawmenu', 'http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL027824#lawmenu', 'http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL027824#lawmenu', 'http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL027824#lawmenu', 'http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL027824#lawmenu', 'http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL027824#lawmenu', 'http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL027824#lawmenu', 'http://erss.aec.gov.tw/law/LawContentSource.aspx?id=FL027824
# ...

# %%
import re
url = 'https://113.215.20.136:9011/113.215.6.77/c3pr90ntcya0/youku/6981496DC9913B8321BFE4A4E73/0300010E0C51F10D86F80703BAF2B1ADC67C80-E0F6-4FF8-B570-7DC5603F9F40.flv'
pattern = 'http://(.*?):9011/'
out = re.sub(pattern, 'http://127.0.0.1:9091/', url)
print (out)
# Out:
# https://113.215.20.136:9011/113.215.6.77/c3pr90ntcya0/youku/6981496DC9913B8321BFE4A4E73/0300010E0C51F10D86F80703BAF2B1ADC67C80-E0F6-4FF8-B570-7DC5603F9F40.flv

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-fec61a5e8ea2> in <module>
#       2 cc=["href"]
#       3 pattern ='LawContentSource.aspx'
# ----> 4 out = re.sub(pattern,'LawContent.aspx',a_tags)
#       5 print (out)
#
# c:\python\lib\re.py in sub(pattern, repl, string, count, flags)
#     190     a callable, it's passed the Match object and must return
#     191     a replacement string to be used."""
# --> 192     return _compile(pattern, flags).sub(repl, string, count)
#     193
#     194 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-136-72aa87308f08> in <module>
# ----> 1 print(a_tags_["href"])
#
# NameError: name 'a_tags_' is not defined

# %%
driver = webdriver.Chrome(executable_path='chromedriver.exe', chrome_options=options)
for url in kt:
    driver.get(url)
    driver.implicitly_wait(30)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.implicitly_wait(30)
    posts=soup.select('#content > div > div.well.law-reg.law-content')
    for post in posts:
        pp=(post["href"])
        post = re.sub('LawContent','LawContentSource',pp)
        driver.implicitly_wait(30)
        for b in b_tags:
            print(b.text)

# %%
driver = webdriver.Chrome(executable_path='chromedriver.exe', chrome_options=options)
for url in kt:
    driver.get(url)
    driver.implicitly_wait(30)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.implicitly_wait(30)
    b_tags=soup.select('#content > div > div.well.law-reg.law-content')
    driver.implicitly_wait(30)
    for b in b_tags:
        print(b.text)
# Out:
# 第 1 條
# 為選定低放射性廢棄物最終處置設施（以下簡稱處置設施）場址，並符合
# 安全及環境保護之要求，特制定本條例。本條例未規定者，適用其他法律
# 之規定。
#
# 第 2 條
# 本條例之主管機關為行政院原子能委員會；主辦機關為經濟部。
#
# 第 3 條
# 本條例用詞定義如下：
# 一、放射性廢棄物：指具有放射性或受放射性物質污染之廢棄物，包括備
#     供最終處置之用過核子燃料。
# 二、低放射性廢棄物：指除備供最終處置之用過核子燃料或其經再處理所
#     產生之萃取殘餘物以外之放射性廢棄物。
# 三、最終處置：指放射性廢棄物之永久隔離處置。
# 四、潛在場址：指依選址計畫經區域篩選及場址初步調查，所選出符合第
#     四條規定之場址。
# 五、建議候選場址：指由選址計畫選出之潛在場址或縣（市）自願提出申
#     請經審查通過者，遴選二個以上並經主辦機關核定及公告之場址。
# 六、候選場址：經當地縣（市）公民投票同意之建議候選場址。
#
# 第 4 條
# 處置設施場址，不得位於下列地區：
# 一、活動斷層或地質條件足以影響處置設施安全之地區。
# 二、地球化學條件不利於有效抑制放射性核種污染擴散，並足以影響處置
#     設施安全之地區。
# 三、地表或地下水文條件足以影響處置設施安全之地區。
# 四、高人口密度之地區。
# 五、其他依法不得開發之地區。
# 前項地區之範圍及認定標準，於本條例施行後六個月內，由主管機關會商
# 相關機關定之。
#
# 第 5 條
# 主辦機關應自本條例施行之日起三個月內，設處置設施場址選擇小組（以
# 下簡稱選址小組），依本條例規定執行處置設施之選址工作。
# 前項選址小組成員人數十七人至二十一人，由相關機關代表、專家學者組
# 成，其中專家學者人數不得少於五分之三；小組成員產生方式、任期及小
# 組會議召開、決議方式等設置規定，由主辦機關擬訂，報請行政院核定。
#
# 第 6 條
# 主辦機關應會商主管機關選定或指定全國主要低放射性廢棄物產出機構為
# 處置設施選址之作業者（以下簡稱選址作業者）。
# 選址作業者應提供選址小組有關處置設施選址之資料，並執行場址調查、
# 安全分析、公眾溝通及土地取得等工作，且應於主辦機關設置之網站，按
# 季公開處置設施場址調查進度等相關資料。
#
# ...
